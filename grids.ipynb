# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import riesling as rl
prefix='grids'
# !rm {prefix}*.h5

# %%
mat = 64
snr = 50
nchan = 2
# !riesling phantom {prefix} --shepp_logan --matrix={mat} --snr={snr} --channels={nchan}
# !riesling sdc --sdc=pipe {prefix}.h5
# Out:
# [10:47:22] Welcome to RIESLING
# [10:47:22] Command: phantom
# [10:47:22] Using 8 threads
# [10:47:22] Using 4096 hi-res spokes
# [10:47:22] Matrix Size: 64 64 64 Voxel Size: 3.75 3.75 3.75
# [10:47:22] Read points: 64 Spokes: 4096
# [10:47:22] Created trajectory object with 4096 spokes
# [10:47:22] Constructing bird-cage sensitivities with 2 channels in 1 rings
# [10:47:22] Mapping to grid size 128
# [10:47:22] Calculating mapping
# [10:47:22] Removing empty buckets
# [10:47:22] Removed 0 empty buckets, 64 remaining
# [10:47:22] Total points 262144
# [10:47:22] Frame weights: 1
# [10:47:22] Planning 2 128x128x128 FFTs with 8 threads
# [10:47:22] Planning 1 128x128x128 FFTs with 8 threads
# [10:47:22] Apodization size 64,64,64 scale factor: 1448.1547
# [10:47:22] Drawing 3D Shepp Logan Phantom. Intensity 100
# [10:47:22] Sampling hi-res non-cartesian
# [10:47:22] Adding noise effective level 7.071068
# [10:47:22] Opened file to write: grids.h5
# ...

# %%
# !riesling grid {prefix}.h5 --sdc=grids-sdc.h5
rl.grid.planes(f'{prefix}-grid.h5')
# Out:
# [10:49:18] Welcome to RIESLING
# [10:49:18] Command: grid
# [10:49:18] Using 8 threads
# [10:49:18] Opened file to read: grids.h5
# [10:49:18] Created trajectory object with 4096 spokes
# [10:49:18] Mapping to grid size 128
# [10:49:18] Calculating mapping
# [10:49:18] Removing empty buckets
# [10:49:18] Removed 0 empty buckets, 64 remaining
# [10:49:18] Total points 262144
# [10:49:18] Frame weights: 1
# [10:49:18] Opened file to write: grids-grid.h5
# [10:49:18] Opened file to read: grids-sdc.h5
# [10:49:18] Reading non-cartesian volume 0
# [10:49:18] Wrote cartesian k-space. Took 405 ms
# [10:49:18] Saved wisdom to "/Users/tobias/.riesling-wisdom"
